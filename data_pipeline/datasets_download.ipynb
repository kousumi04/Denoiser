# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("okhater/lolv2-real")
# Out:
# Resolving data files:   0%|          | 0/1578 [00:00<?, ?it/s]
# ...
# Train/Input/00623.png:   0%|          | 0.00/321k [00:00<?, ?B/s]
# Train/Input/00624.png:   0%|          | 0.00/327k [00:00<?, ?B/s]
# Train/Input/00630.png:   0%|          | 0.00/322k [00:00<?, ?B/s]
# Train/Input/00622.png:   0%|          | 0.00/322k [00:00<?, ?B/s]
# Train/Input/00636.png:   0%|          | 0.00/285k [00:00<?, ?B/s]
# Train/Input/00633.png:   0%|          | 0.00/352k [00:00<?, ?B/s]
# Train/Input/00621.png:   0%|          | 0.00/341k [00:00<?, ?B/s]
# Train/Input/00631.png:   0%|          | 0.00/306k [00:00<?, ?B/s]
# Train/Input/00634.png:   0%|          | 0.00/351k [00:00<?, ?B/s]
# Train/Input/00629.png:   0%|          | 0.00/324k [00:00<?, ?B/s]
# Train/Input/00627.png:   0%|          | 0.00/329k [00:00<?, ?B/s]
# Train/Input/00625.png:   0%|          | 0.00/327k [00:00<?, ?B/s]
# Train/Input/00635.png:   0%|          | 0.00/285k [00:00<?, ?B/s]
# ...

# %%
print(ds)
print(ds.keys())        # if DatasetDict
print(len(ds["train"])) # adjust split name if needed
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 1578
#     })
# })
# dict_keys(['train'])
# 1578

# %%
sample = ds["train"][0]
print(sample["label"])
sample["image"]
# Out:
# 0
# <PIL.Image.Image image mode=RGB size=600x400>
